# %%
import pandas as pd

# %%
columnas = ['Nombre','Edad persona','Ocupacion']

datos = [
    ['Bruno',29,'Ingeniero'],
    ['Pablo',35,'Medico'],
    ['Maria',23,'Abogada']
]

df = pd.DataFrame(data=datos, columns=columnas)
df

# %%
df.drop(2,axis=0,inplace=True)

# %%
df
